# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('1.csv')
plt.xlabel('Number of Vertices')
plt.ylabel('Time in microseconds')
plt.title('Results of Cycle Finding Algorithm')
plt.legend()
plt.plot(df["Vertices"], df["Time"])
plt.savefig('1.png', dpi=1200)
# Out:
# No handles with labels found to put in legend.

# %%
df = pd.read_csv('11.csv')
plt.xlabel('Number of Vertices')
plt.ylabel('Time in milliseconds')
plt.title('Results of Finding Minimum Spanning Tree for "Sparse" graphs')
plt.legend()
plt.plot(df["Vertices"], df["Time"])
plt.savefig('2.png', dpi = 1200)
# Out:
# No handles with labels found to put in legend.
